# %% [markdown]
# # Task 2

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Preprocessing

# %%
df = pd.read_csv("cancer_patient_dataset.csv")
df.head(5)
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 0                     4             3                     2  ...        3
# 1                     3             4                     2  ...        1
# 2                     5             5                     4  ...        8
# 3                     7             6                     7  ...        4
# 4                     7             7                     6  ...        3
#
# ...

# %% [markdown]
# ## Data Analysis

# %%
#Part C:
df['Level'].unique()
# Out:
# array(['Low', 'Medium', 'High'], dtype=object)

# %%
#Part D:
print("Total Columns:", len(df.columns))
print("\nTop 50 records:\n", df.head(50))
print("\nBottom 30 records:\n", df.tail(30))
print("\nDataset Info:\n")
df.info()
print("\nShape:", df.shape)
print("\nSize:", df.size)
# Out:
# Total Columns: 26
#
# Top 50 records:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0       0         P1   33       1              2            4             5
# 1       1        P10   17       1              3            1             5
# 2       2       P100   35       1              4            5             6
# 3       3      P1000   37       1              7            7             7
# 4       4       P101   46       1              6            8             7
# 5       5       P102   35       1              4            5             6
# 6       6       P103   52       2              2            4             5
# 7       7       P104   28       2              3            1             4
# 8       8       P105   35       2              4            5             6
# 9       9       P106   46       1              2            3             4
# 10     10       P107   44       1              6            7             7
# ...

# %%
#Part E:
print("Number of Columns:", df.shape[1])
print("Total Samples:", df.shape[0])
# Out:
# Number of Columns: 26
# Total Samples: 1000

# %%
#Part F:
# Numerical
print(df['Level'].value_counts())

# Graphical
sns.countplot(x='Level', data=df)
plt.title("Distribution of Target Variable (Level)")
plt.show()
# Out:
# Level
# High      365
# Medium    332
# Low       303
# Name: count, dtype: int64

# %%
#Part G:
new_df = df.loc[550:900, "Gender":"Coughing of Blood"]

new_df.to_csv("subset_loc.csv", index=False)

print("Mean:\n", new_df.mean())
print("Median:\n", new_df.median())
print("Mode:\n", new_df.mode().iloc[0])
print("Standard Deviation:\n", new_df.std())
print("Minimum:\n", new_df.min())
print("Maximum:\n", new_df.max())
# Out:
# Mean:
#  Gender                  1.396011
# Air Pollution           3.988604
# Alcohol use             4.749288
# Dust Allergy            5.319088
# OccuPational Hazards    4.974359
# Genetic Risk            4.726496
# chronic Lung Disease    4.472934
# Balanced Diet           4.615385
# Obesity                 4.635328
# Smoking                 4.045584
# Passive Smoker          4.333333
# Chest Pain              4.572650
# Coughing of Blood       5.022792
# dtype: float64
# Median:
#  Gender                  1.0
# Air Pollution           4.0
# Alcohol use             5.0
# Dust Allergy            6.0
# OccuPational Hazards    5.0
# Genetic Risk            5.0
# chronic Lung Disease    5.0
# Balanced Diet           5.0
# Obesity                 4.0
# Smoking                 3.0
# Passive Smoker          4.0
# Chest Pain              4.0
# Coughing of Blood       4.0
# dtype: float64
# Mode:
#  Gender                  1
# Air Pollution           6
# Alcohol use             8
# ...

# %%
# Part H

last_20 = df.iloc[-20:, df.columns.get_loc("Shortness of Breath"):df.columns.get_loc("Frequent Cold")+1]
last_20.to_csv("last20_iloc.csv", index=False)

print("Mean:\n", last_20.mean())
print("Median:\n", last_20.median())
print("Mode:\n", last_20.mode().iloc[0])
print("Std Dev:\n", last_20.std())
print("Minimum:\n", last_20.min())
print("Maximum:\n", last_20.max())
# Out:
# Mean:
#  Shortness of Breath         5.40
# Wheezing                    3.65
# Swallowing Difficulty       3.95
# Clubbing of Finger Nails    4.05
# Frequent Cold               4.65
# dtype: float64
# Median:
#  Shortness of Breath         5.0
# Wheezing                    2.0
# Swallowing Difficulty       4.0
# Clubbing of Finger Nails    4.0
# Frequent Cold               4.0
# dtype: float64
# Mode:
#  Shortness of Breath         9.0
# Wheezing                    1.0
# Swallowing Difficulty       4.0
# Clubbing of Finger Nails    4.0
# Frequent Cold               6.0
# Name: 0, dtype: float64
# Std Dev:
#  Shortness of Breath         2.542274
# Wheezing                    2.621269
# Swallowing Difficulty       2.372540
# Clubbing of Finger Nails    1.791060
# Frequent Cold               1.496487
# dtype: float64
# Minimum:
#  Shortness of Breath         2
# Wheezing                    1
# Swallowing Difficulty       1
# Clubbing of Finger Nails    2
# Frequent Cold               2
# ...

# %%
# Part I

records = df.iloc[[110, 220, 360, 440, 656, 778, 202, 889], :]
print("Extracted Records:")
print(records)
avg_alcohol = records["Alcohol use"].mean()
print("\nAverage Alcohol Use of these records:", avg_alcohol)
# Out:
# Extracted Records:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 110    110       P198   18       2              6            8             7
# 220    220       P297   25       2              4            5             6
# 360    360       P422   19       1              3            2             4
# 440    440       P495   44       1              6            7             7
# 656    656        P69   52       1              6            8             7
# 778    778         P8   27       2              3            1             4
# 202    202       P280   53       1              6            8             7
# 889    889         P9   73       1              5            6             6
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# 110                     7             7                     6  ...        3
# 220                     5             5                     4  ...        8
# ...
